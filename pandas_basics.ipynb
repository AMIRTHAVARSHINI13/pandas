# %% [markdown]
# <a href="https://colab.research.google.com/github/AMIRTHAVARSHINI13/pandas/blob/main/pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
a=np.array([1,2,3,45,56])
a
# Out:
# array([ 1,  2,  3, 45, 56])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[3]
# Out:
# 45

# %%
s=pd.Series([1,4,2,3,56,78])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0     1
# 1     4
# 2     2
# 3     3
# 4    56
# 5    78
# dtype: int64

# %%
s[3]
# Out:
# 3

# %%
s.drop(4,inplace=True)

# %%
s.iloc[0]
# Out:
# 1

# %%
s.loc[1]
# Out:
# 4

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 3, 5], dtype='int64')

# %%
ss = pd.Series([1,4,2,3,56,78], index=['a','b','c','as[a]','e','f'])
ss
# Out:
# a         1
# b         4
# c         2
# as[a]     3
# e        56
# f        78
# dtype: int64

# %%
ss.loc['a']
# Out:
# 1

# %%
ss.iloc[4]
# Out:
# 56

# %%
data=[['alex',13,'13-10-2008'],['bob',None,None],['kisshore',None,'31-12-2008']]
data
# Out:
# [['alex', 13, '13-10-2008'],
#  ['bob', None, None],
#  ['kisshore', None, '31-12-2008']]

# %%
df=pd.DataFrame(data)
df
# Out:
#           0     1           2
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df[0:1]
# Out:
#       0     1           2
# 0  alex  13.0  13-10-2008

# %%
df[0:3]
# Out:
#           0     1           2
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df[0][0]
# Out:
# 'alex'

# %%
df[[0,2]] #specified columns
# Out:
#           0           2
# 0      alex  13-10-2008
# 1       bob        None
# 2  kisshore  31-12-2008

# %%
df[1:2]
# Out:
#      0   1     2
# 1  bob NaN  None

# %%
df=pd.DataFrame(data,columns=['first','age','dob'])
df
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df['first']
# Out:
# 0        alex
# 1         bob
# 2    kisshore
# Name: first, dtype: object

# %%
df['age']
# Out:
# 0    13.0
# 1     NaN
# 2     NaN
# Name: age, dtype: float64

# %%
df['first'][2]
# Out:
# 'kisshore'

# %%
df.loc[0,'first']
# Out:
# 'alex'

# %%
df.iloc[:1]
# Out:
#   first   age         dob
# 0  alex  13.0  13-10-2008

# %%
df[0:2]
# Out:
#   first   age         dob
# 0  alex  13.0  13-10-2008
# 1   bob   NaN        None

# %%
s=pd.Series([1,2,3])
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()
s
# Out:
# array([1, 2, 3])

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df.tail(1)
# Out:
#       first  age         dob
# 2  kisshore  NaN  31-12-2008

# %%
df.head()
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df.head(1)
# Out:
#   first   age         dob
# 0  alex  13.0  13-10-2008

# %%
df.tail(-2)
# Out:
#       first  age         dob
# 2  kisshore  NaN  31-12-2008

# %%
#None,'',' ','-','?','Nil',np.nan(not a number)

# %%
df.isnull()
# Out:
#    first    age    dob
# 0  False  False  False
# 1  False   True   True
# 2  False   True  False

# %%
df.isnull().sum()
# Out:
# first    0
# age      2
# dob      1
# dtype: int64

# %%
data1=[['alex',13,'13-10-2008'],['bob',None,None],['kisshore',None,'31-12-2008'],['kutta',10,'18-12-2003'],['rakshi',None,np.nan]]
data1
# Out:
# [['alex', 13, '13-10-2008'],
#  ['bob', None, None],
#  ['kisshore', None, '31-12-2008'],
#  ['kutta', 10, '18-12-2003'],
#  ['rakshi', None, nan]]

# %%
d1=pd.DataFrame(data1)
d1
# Out:
#           0     1           2
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008
# 3     kutta  10.0  18-12-2003
# 4    rakshi   NaN         NaN

# %%
d1.isnull()
# Out:
#        0      1      2
# 0  False  False  False
# 1  False   True   True
# 2  False   True  False
# 3  False  False  False
# 4  False   True   True

# %%
d1.dropna()
# Out:
#        0     1           2
# 0   alex  13.0  13-10-2008
# 3  kutta  10.0  18-12-2003

# %%
d1
# Out:
#           0     1           2
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008
# 3     kutta  10.0  18-12-2003
# 4    rakshi   NaN         NaN

# %%
d1=pd.DataFrame(data1,columns=['first','age','dob'])
d1
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008
# 3     kutta  10.0  18-12-2003
# 4    rakshi   NaN         NaN

# %%
d1.drop(['age'],axis=1,inplace=True)
d1
# Out:
#       first         dob
# 0      alex  13-10-2008
# 1       bob        None
# 2  kisshore  31-12-2008
# 3     kutta  18-12-2003
# 4    rakshi         NaN

# %%
a
a>40
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>40]
# Out:
# array([45, 56])

# %%
a[a%2!=0]
# Out:
# array([ 1,  3, 45])

# %%
b=np.array([1,2,7,8,90,10])
b[b%2==0]
# Out:
# array([ 2,  8, 90, 10])

# %%
df
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df['first'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2     True
# Name: first, dtype: bool

# %%
df['first'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# Name: first, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['first', 'age', 'dob'], dtype='object')]
# 2
# first     object
# age      float64
# dob       object
# dtype: object
# Index(['first', 'age', 'dob'], dtype='object')
# [['alex' 13.0 '13-10-2008']
#  ['bob' nan None]
#  ['kisshore' nan '31-12-2008']]

# %%
df.head()
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df.tail()
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df3=pd.concat([df,df])
df3
# Out:
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008
# 0      alex  13.0  13-10-2008
# 1       bob   NaN        None
# 2  kisshore   NaN  31-12-2008

# %%
df.describe()
# Out:
#         age
# count   1.0
# mean   13.0
# std     NaN
# min    13.0
# 25%    13.0
# 50%    13.0
# 75%    13.0
# max    13.0

# %%
df.age
# Out:
# 0    13.0
# 1     NaN
# 2     NaN
# Name: age, dtype: float64

# %%
df['first']
# Out:
# 0        alex
# 1         bob
# 2    kisshore
# Name: first, dtype: object

# %%
df[['first','dob']]
# Out:
#       first         dob
# 0      alex  13-10-2008
# 1       bob        None
# 2  kisshore  31-12-2008

# %%
df.loc[0][0]
# Out:
# 'alex'

# %%
df.loc[0]['first']
# Out:
# 'alex'

# %%
df.loc[2]['first']
# Out:
# 'kisshore'

# %%
df.iloc[0,2]
# Out:
# '13-10-2008'

# %%
df.iloc[0]['dob']
# Out:
# '13-10-2008'

# %%
df["dob"][1]='21-04-2003'
df
# Out:
# <ipython-input-332-f915aec15639>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["dob"][1]='21-04-2003'
#       first   age         dob
# 0      alex  13.0  13-10-2008
# 1       bob   NaN  21-04-2003
# 2  kisshore   NaN  31-12-2008

# %%
df.iloc[1][2]
# Out:
# '21-04-2003'

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/HTML")
df
# Out:
# [                                                    0  \
#  0   The official logo of the latest version, HTML5[1]
#  1                                  Filename extension
#  2                                 Internet media type
#  3                                           Type code
#  4                       Uniform Type Identifier (UTI)
#  5                                        Developed by
#  6                                     Initial release
#  7                                      Latest release
#  8                                      Type of format
#  9                                       Container for
#  10                                       Contained by
#  11                                      Extended from
#  12                                        Extended to
#  13                                       Open format?
#  14                                            Website
#
#                                                      1
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.item_price[0])
# Out:
# str

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-341-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
df.item_price*100
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Chicken Salad Bowl'].choice_description.nunique()
# Out:
# 78

# %%
df.dropna(inplace=True)

# %%
df.choice_description
# Out:
# 1                                            [Clementine]
# 2                                                 [Apple]
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 3376, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_name=='Chicken Bowl') & (df.item_price < 10)].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
movies = pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.star_rating>=8)&(movies.genre=="Action")].sort_values(['duration'])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 37           8.6                         Raiders of the Lost Ark
# 261          8.1                                     Elite Squad
# 240          8.1                            The Bourne Ultimatum
# ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating'] and ['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# ...

# %%
movies[movies.actors_list.str.contains('Johnny Depp')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating                                              title  \
# 271          8.1  Pirates of the Caribbean: The Curse of the Bla...
# 379          8.0                                Edward Scissorhands
# 418          7.9                                            Ed Wood
# 547          7.8                                  Finding Neverland
# 562          7.8                        What's Eating Gilbert Grape
# 560          7.8                                      Donnie Brasco
# 608          7.7                     Fear and Loathing in Las Vegas
# 594          7.7                                           Dead Man
# 725          7.6                                               Blow
# 869          7.5                          A Nightmare on Elm Street
# 904          7.5     Sweeney Todd: The Demon Barber of Fleet Street
# 951          7.4                                      Sleepy Hollow
#
#     content_rating      genre  duration  \
# ...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(how='all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Colors Reported'].isnull().sum()
# Out:
# 15359

# %%
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','max','min'])
# Out:
# mean     37.045455
# max     247.000000
# min       0.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','max','min'])
# Out:
#                      mean  max  min
# continent
# Africa          61.471698  376    0
# Asia            37.045455  247    0
# Europe         193.777778  361    0
# North America  145.434783  285    1
# Oceania         89.687500  306    0
# South America  175.083333  333   93
